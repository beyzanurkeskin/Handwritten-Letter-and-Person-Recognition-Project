# %%
import os
import cv2
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
import matplotlib.pyplot as plt
import time

# %%
# List of subfolders
subfolders = ["beyza", "zeynep", "ezgi"]

# Set the path to the root directory
root_path = r"C:\Users\Beyza\Desktop\project1"

images = []
labels = []

valid_extensions = {".jpg", ".jpeg", ".png"}

for subfolder in subfolders:
    subfolder_path = os.path.join(root_path, subfolder)

    for folder_name in os.listdir(subfolder_path):
        folder_path = os.path.join(subfolder_path, folder_name)
        if os.path.isdir(folder_path):
            for file_name in os.listdir(folder_path):
                if any(file_name.lower().endswith(ext) for ext in valid_extensions):
                    image_path = os.path.join(folder_path, file_name)
                    label = file_name.split('_')[2]
                    img = cv2.imread(image_path)
                    if img is None:
                        print(f"Failed to load image: {image_path}")
                    else:
                        img = cv2.resize(img, (64, 64))
                        images.append(img)
                        labels.append(label)

images = np.array(images)
labels = np.array(labels)

label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

images = images / 255.0

X_train, X_test, y_train, y_test = train_test_split(images, labels_encoded, test_size=0.2, random_state=42)

# Define the CNN model with glorot_uniform initializer
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(len(label_encoder.classes_), activation='relu'))


# Compile the model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss:.4f}, Test accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.0094 - loss: 12.8532 - val_accuracy: 0.0000e+00 - val_loss: 12.0442
# Epoch 2/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.0055 - loss: 12.4915 - val_accuracy: 0.0000e+00 - val_loss: 9.0850
# Epoch 3/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0055 - loss: 5.8364 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 4/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.0046 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 5/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.0044 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 6/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.0084 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 7/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.0062 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 8/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.0020 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 9/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.0081 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 10/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.0069 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 11/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.0035 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 12/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.0061 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 13/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.0055 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 14/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.0039 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 15/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.0029 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 16/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.0020 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 17/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.0021 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 18/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.0093 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 19/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.0052 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.0027 - loss: 5.3471 - val_accuracy: 0.0079 - val_loss: 5.3471
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0078 - loss: 5.3471
# Test loss: 5.3471, Test accuracy: 0.79%
