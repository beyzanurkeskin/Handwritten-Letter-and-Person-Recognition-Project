# %% [markdown]
# ## Importing libraries

# %%
import os
import cv2
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
import matplotlib.pyplot as plt
import time
from tensorflow.keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# %% [markdown]
# ## Importing the Dataset

# %%
# List of subfolders
subfolders = ["beyza", "zeynep", "ezgi"]

# Set the path to the root directory
root_path = r"C:\Users\Beyza\Desktop\project"  # the root directory where the images are stored

images = []
labels = []

valid_extensions = {".jpg", ".jpeg", ".png"}

for subfolder in subfolders:
    subfolder_path = os.path.join(root_path, subfolder)

    for folder_name in os.listdir(subfolder_path):
        folder_path = os.path.join(subfolder_path, folder_name)
        if os.path.isdir(folder_path):
            for file_name in os.listdir(folder_path):
                if any(file_name.lower().endswith(ext) for ext in valid_extensions):
                    image_path = os.path.join(folder_path, file_name)
                    label = file_name.split('_')[0]
                    # Extract only the part before the decimal point
                    label = label.split('.')[0]
                    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)                    
                    if img is None:
                        print(f"Failed to load image: {image_path}")
                    else:
                        img = cv2.resize(img, (64, 64))
                        img = np.expand_dims(img, axis=-1)
                        images.append(img)
                        labels.append(label)

# %% [markdown]
# ## Preprocessing

# %%
images = np.array(images)
labels = np.array(labels)

label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

images = images / 255.0

# %% [markdown]
# ## Splitting the Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# ##  Fitting the Model

# %%
# Define the CNN model with glorot_uniform initializer
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 1)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))
# Out:
# C:\Users\Beyza\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
# Define the optimizer with a custom learning rate (e.g., 0.001)
custom_learning_rate = 0.001
custom_optimizer = Adam(learning_rate=custom_learning_rate)

# %%
# Create an image data generator
datagen = ImageDataGenerator(rescale=1./255)

# %%
# Compile the model with the custom optimizer
model.compile(optimizer=custom_optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Create a generator for training data
train_generator = datagen.flow(X_train, y_train, batch_size=32)

# Create a generator for validation data
validation_generator = datagen.flow(X_test, y_test, batch_size=32)

# %%
# Record the start time before compilation
start_time = time.time()

# %%
# Train the model
history_2 = model.fit(X_train,y_train, epochs=40, batch_size=64, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 31s 107ms/step - accuracy: 0.0534 - loss: 3.8439 - val_accuracy: 0.1490 - val_loss: 3.2179
# Epoch 2/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 103ms/step - accuracy: 0.1624 - loss: 3.1445 - val_accuracy: 0.1319 - val_loss: 3.4576
# Epoch 3/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.2213 - loss: 2.8728 - val_accuracy: 0.2461 - val_loss: 2.7597
# Epoch 4/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 28s 104ms/step - accuracy: 0.2843 - loss: 2.6110 - val_accuracy: 0.2737 - val_loss: 2.6708
# Epoch 5/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.3267 - loss: 2.4157 - val_accuracy: 0.3231 - val_loss: 2.4098
# Epoch 6/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - accuracy: 0.3725 - loss: 2.2302 - val_accuracy: 0.3093 - val_loss: 2.4514
# Epoch 7/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.4182 - loss: 2.0536 - val_accuracy: 0.3245 - val_loss: 2.4721
# Epoch 8/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - accuracy: 0.4122 - loss: 2.0676 - val_accuracy: 0.3302 - val_loss: 2.5016
# Epoch 9/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 100ms/step - accuracy: 0.4998 - loss: 1.7539 - val_accuracy: 0.4312 - val_loss: 2.0048
# Epoch 10/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 100ms/step - accuracy: 0.5642 - loss: 1.5334 - val_accuracy: 0.2480 - val_loss: 3.4448
# Epoch 11/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.5333 - loss: 1.6683 - val_accuracy: 0.3462 - val_loss: 2.5276
# Epoch 12/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.5170 - loss: 1.7388 - val_accuracy: 0.5058 - val_loss: 1.7761
# Epoch 13/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.6810 - loss: 1.0883 - val_accuracy: 0.4837 - val_loss: 1.8959
# Epoch 14/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.7058 - loss: 1.0108 - val_accuracy: 0.4899 - val_loss: 1.8871
# Epoch 15/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 33s 123ms/step - accuracy: 0.6831 - loss: 1.0934 - val_accuracy: 0.5434 - val_loss: 1.6406
# Epoch 16/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 35s 131ms/step - accuracy: 0.7568 - loss: 0.8199 - val_accuracy: 0.4103 - val_loss: 2.4271
# Epoch 17/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 44s 168ms/step - accuracy: 0.7116 - loss: 1.0197 - val_accuracy: 0.5543 - val_loss: 1.6335
# Epoch 18/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 38s 145ms/step - accuracy: 0.8208 - loss: 0.6206 - val_accuracy: 0.5726 - val_loss: 1.6029
# Epoch 19/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 35s 134ms/step - accuracy: 0.8438 - loss: 0.5469 - val_accuracy: 0.5072 - val_loss: 1.9794
# Epoch 20/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 38s 144ms/step - accuracy: 0.7919 - loss: 0.7242 - val_accuracy: 0.5826 - val_loss: 1.6717
# Epoch 21/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 40s 151ms/step - accuracy: 0.8682 - loss: 0.4597 - val_accuracy: 0.5369 - val_loss: 1.9293
# Epoch 22/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 43s 162ms/step - accuracy: 0.8223 - loss: 0.6151 - val_accuracy: 0.6020 - val_loss: 1.5879
# Epoch 23/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 33s 126ms/step - accuracy: 0.9087 - loss: 0.3312 - val_accuracy: 0.6068 - val_loss: 1.6321
# Epoch 24/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 36s 136ms/step - accuracy: 0.9145 - loss: 0.3048 - val_accuracy: 0.5590 - val_loss: 2.0001
# Epoch 25/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 38s 143ms/step - accuracy: 0.9014 - loss: 0.3349 - val_accuracy: 0.6146 - val_loss: 1.6559
# Epoch 26/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 37s 138ms/step - accuracy: 0.9309 - loss: 0.2498 - val_accuracy: 0.5866 - val_loss: 1.8911
# Epoch 27/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 34s 130ms/step - accuracy: 0.8555 - loss: 0.5151 - val_accuracy: 0.6199 - val_loss: 1.6937
# Epoch 28/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 34s 130ms/step - accuracy: 0.9420 - loss: 0.2172 - val_accuracy: 0.6227 - val_loss: 1.7652
# Epoch 29/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 43s 163ms/step - accuracy: 0.9549 - loss: 0.1729 - val_accuracy: 0.6108 - val_loss: 1.8722
# Epoch 30/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 37s 138ms/step - accuracy: 0.9559 - loss: 0.1653 - val_accuracy: 0.6047 - val_loss: 1.9905
# Epoch 31/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 38s 143ms/step - accuracy: 0.9414 - loss: 0.1991 - val_accuracy: 0.6063 - val_loss: 2.0083
# Epoch 32/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 34s 130ms/step - accuracy: 0.9435 - loss: 0.1877 - val_accuracy: 0.6063 - val_loss: 2.0850
# Epoch 33/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 40s 150ms/step - accuracy: 0.9590 - loss: 0.1475 - val_accuracy: 0.6251 - val_loss: 1.9906
# Epoch 34/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 41s 150ms/step - accuracy: 0.9406 - loss: 0.2016 - val_accuracy: 0.5807 - val_loss: 2.4840
# Epoch 35/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.8990 - loss: 0.3624 - val_accuracy: 0.6365 - val_loss: 1.9187
# Epoch 36/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 36s 136ms/step - accuracy: 0.9713 - loss: 0.1112 - val_accuracy: 0.6455 - val_loss: 1.8838
# Epoch 37/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 47s 177ms/step - accuracy: 0.9760 - loss: 0.0977 - val_accuracy: 0.6529 - val_loss: 1.9535
# Epoch 38/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 42s 159ms/step - accuracy: 0.9657 - loss: 0.1140 - val_accuracy: 0.6137 - val_loss: 2.1549
# Epoch 39/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 38s 142ms/step - accuracy: 0.9501 - loss: 0.1714 - val_accuracy: 0.5973 - val_loss: 2.3356
# Epoch 40/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 38s 144ms/step - accuracy: 0.9554 - loss: 0.1456 - val_accuracy: 0.6391 - val_loss: 2.0369

# %%
# Record the end time after compilation
end_time = time.time()

# Calculate and print the compilation time
compilation_time = end_time - start_time
print(f"Model compilation time: {compilation_time} seconds")
# Out:
# Model compilation time: 1372.8695952892303 seconds

# %% [markdown]
# ## Results

# %%
# Plot accuracy and validation accuracy graphs
plt.figure(figsize=(16, 8))
plt.plot(history_2.history['accuracy'], label='Training Accuracy',color="#1D8FAD")
plt.plot(history_2.history['val_accuracy'], label='Validation Accuracy',color="#AD211D")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss:.4f}, Test accuracy: {accuracy * 100:.2f}%')
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.6483 - loss: 1.9973
# Test loss: 2.0351, Test accuracy: 63.91%

# %% [markdown]
# ## Plotting 10 True Samples

# %%
# Use the trained model to predict classes on the test set
predictions = model.predict(X_test)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Decode the encoded labels back to the original labels
decoded_predicted_labels = label_encoder.inverse_transform(predicted_labels)
decoded_true_labels = label_encoder.inverse_transform(y_test)

# Display 10 true predicted images in a subplot 
num_wrong_images_to_display = 10
num_columns = 5
num_rows = 2
count = 0

plt.figure(figsize=(16, 8))  

for i in range(len(X_test)):
    if decoded_true_labels[i] == decoded_predicted_labels[i]:
        plt.subplot(num_rows, num_columns, count + 1)
        plt.imshow(X_test[i])
        plt.title(f"True: {decoded_true_labels[i]}\nPredicted: {decoded_predicted_labels[i]}")
        count += 1

        if count == num_wrong_images_to_display:
            break

plt.tight_layout()
plt.show()
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step

# %% [markdown]
# ## Plotting 10 False Samples

# %%
# Use the trained model to predict classes on the test set
predictions = model.predict(X_test)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Decode the encoded labels back to the original labels
decoded_predicted_labels = label_encoder.inverse_transform(predicted_labels)
decoded_true_labels = label_encoder.inverse_transform(y_test)

# Display 10 wrong predicted images in a subplot
num_wrong_images_to_display = 10
num_columns = 5
num_rows = 2
count = 0

plt.figure(figsize=(16, 8))  

for i in range(len(X_test)):
    if decoded_true_labels[i] != decoded_predicted_labels[i]:
        plt.subplot(num_rows, num_columns, count + 1)
        plt.imshow(X_test[i])
        plt.title(f"True: {decoded_true_labels[i]}\nPredicted: {decoded_predicted_labels[i]}")
        count += 1

        if count == num_wrong_images_to_display:
            break

plt.tight_layout()
plt.show()
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step

# %% [markdown]
# ## Statistical Tests

# %%
# Use the trained model to predict classes on the test set
predictions = model.predict(X_test)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Decode the encoded labels back to the original labels
decoded_true_labels = label_encoder.inverse_transform(y_test)

# Obtain confusion matrix
conf_matrix = confusion_matrix(decoded_true_labels, decoded_predicted_labels, labels=label_encoder.classes_)

# Calculate precision, recall, and F1 score for each class
precision = precision_score(decoded_true_labels, decoded_predicted_labels, average=None)
recall = recall_score(decoded_true_labels, decoded_predicted_labels, average=None)
f1 = f1_score(decoded_true_labels, decoded_predicted_labels, average=None)

# Colors for the bars
precision_color = '#229EA6'
recall_color = '#AD211D'
f1_color = '#61439D'
highlight_color = 'black'

# Find the class with the highest precision, recall, and F1 score
max_precision_class = label_encoder.classes_[np.argmax(precision)]
max_recall_class = label_encoder.classes_[np.argmax(recall)]
max_f1_class = label_encoder.classes_[np.argmax(f1)]

# Plot precision, recall, and F1 score for each class in subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot precision
max_precision_index = np.argmax(precision)
axes[0].bar(label_encoder.classes_, precision, color=precision_color, label=f'Max: {max_precision_class}')
axes[0].bar(label_encoder.classes_[max_precision_index], precision[max_precision_index], color=highlight_color)
axes[0].text(max_precision_index, precision[max_precision_index], f'{precision[max_precision_index]:.2f}', ha='center', va='bottom', color=highlight_color)
axes[0].set_title('Precision')
axes[0].set_ylabel('Precision')
axes[1].set_ylim(0.1, 1.0)
axes[0].legend()

# Plot recall
max_recall_index = np.argmax(recall)
axes[1].bar(label_encoder.classes_, recall, color=recall_color, label=f'Max: {max_recall_class}')
axes[1].bar(label_encoder.classes_[max_recall_index], recall[max_recall_index], color=highlight_color)
axes[1].text(max_recall_index, recall[max_recall_index], f'{recall[max_recall_index]:.2f}', ha='center', va='bottom', color=highlight_color)
axes[1].set_title('Recall')
axes[1].set_ylabel('Recall')
axes[1].set_ylim(0.1, 1.0)
axes[1].legend()

# Plot F1 score
max_f1_index = np.argmax(f1)
axes[2].bar(label_encoder.classes_, f1, color=f1_color, label=f'Max: {max_f1_class}')
axes[2].bar(label_encoder.classes_[max_f1_index], f1[max_f1_index], color=highlight_color)
axes[2].text(max_f1_index, f1[max_f1_index], f'{f1[max_f1_index]:.2f}', ha='center', va='bottom', color=highlight_color)
axes[2].set_title('F1 score')
axes[2].set_ylabel('F1 Score')
axes[1].set_ylim(0.1, 1.0)
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step

# %%
# Save the trained model
model.save('person_recognition_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import joblib
joblib.dump(label_encoder, 'person_label_encoder.joblib')
# Out:
# ['person_label_encoder.joblib']
