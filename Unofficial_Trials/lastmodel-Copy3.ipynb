# %%
import os
import cv2
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
import matplotlib.pyplot as plt
import time
from tensorflow.keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# List of subfolders
subfolders = ["beyza", "zeynep", "ezgi"]

# Set the path to the root directory
root_path = r"C:\Users\Beyza\Desktop\project"

images = []
labels = []

valid_extensions = {".jpg", ".jpeg", ".png"}

for subfolder in subfolders:
    subfolder_path = os.path.join(root_path, subfolder)

    for folder_name in os.listdir(subfolder_path):
        folder_path = os.path.join(subfolder_path, folder_name)
        if os.path.isdir(folder_path):
            for file_name in os.listdir(folder_path):
                if any(file_name.lower().endswith(ext) for ext in valid_extensions):
                    image_path = os.path.join(folder_path, file_name)
                    # Extract class information from the file name (assuming it is between the first '_' and the file extension)
                    label = file_name.split('_')[1]
                    img = cv2.imread(image_path)
                    if img is None:
                        print(f"Failed to load image: {image_path}")
                    else:
                        img = cv2.resize(img, (64, 64))
                        images.append(img)
                        labels.append(label)

# %%
# Print unique labels
unique_labels = set(labels)
print("Unique Labels:", unique_labels)
# Out:
# Unique Labels: {'H', 'Gtr', 's', 'A', 'K', 'a', 'q', 'F', 'b', 'g', 'm', 'gtr', 'x', 'w', 'ctr', 'D', 'M', 'l', 'N', 'P', 'T', 'j', 'X', 'd', 'J', 'z', 'Utr', 'L', 'o', 'U', 'Otr', 'p', 'str', 'Y', 'f', 'y', 'O', 'G', 'i', 'utr', 'k', 'S', 'h', 'r', 'v', 'Ctr', 'C', 't', 'V', 'E', 'I', 'c', 'R', ' ', 'Z', 'otr', 'W', 'Q', 'e', 'Str', 'n', 'B', 'u'}

# %%
images = np.array(images)
labels = np.array(labels)

label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

images = images / 255.0

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels_encoded, test_size=0.2, random_state=42)

# %%
# Define the CNN model with glorot_uniform initializer
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))
# Out:
# C:\Users\Beyza\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
# Define the optimizer with a custom learning rate (e.g., 0.001)
custom_learning_rate = 0.001
custom_optimizer = Adam(learning_rate=custom_learning_rate)

# %%
# Create an image data generator
datagen = ImageDataGenerator(rescale=1./255)

# %%
# Compile the model with the custom optimizer
model.compile(optimizer=custom_optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Create a generator for training data
train_generator = datagen.flow(X_train, y_train, batch_size=32)

# Create a generator for validation data
validation_generator = datagen.flow(X_test, y_test, batch_size=32)

# %%
# Record the start time before compilation
start_time = time.time()

# %%
# Train the model
history_2 = model.fit(X_train, y_train, epochs=40, batch_size=64, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 30s 104ms/step - accuracy: 0.0216 - loss: 4.1328 - val_accuracy: 0.0874 - val_loss: 3.8611
# Epoch 2/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 98ms/step - accuracy: 0.1523 - loss: 3.4819 - val_accuracy: 0.2851 - val_loss: 2.7239
# Epoch 3/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 97ms/step - accuracy: 0.3682 - loss: 2.4090 - val_accuracy: 0.4201 - val_loss: 2.1227
# Epoch 4/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 98ms/step - accuracy: 0.5325 - loss: 1.6808 - val_accuracy: 0.5548 - val_loss: 1.6452
# Epoch 5/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 98ms/step - accuracy: 0.6317 - loss: 1.2982 - val_accuracy: 0.5103 - val_loss: 1.7859
# Epoch 6/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 28s 104ms/step - accuracy: 0.6926 - loss: 1.0942 - val_accuracy: 0.4913 - val_loss: 1.9195
# Epoch 7/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 104ms/step - accuracy: 0.7037 - loss: 1.0531 - val_accuracy: 0.6949 - val_loss: 1.1015
# Epoch 8/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 97ms/step - accuracy: 0.8013 - loss: 0.6874 - val_accuracy: 0.6610 - val_loss: 1.1793
# Epoch 9/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.8235 - loss: 0.6185 - val_accuracy: 0.7301 - val_loss: 0.9574
# Epoch 10/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - accuracy: 0.8587 - loss: 0.4980 - val_accuracy: 0.7415 - val_loss: 0.9497
# Epoch 11/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.8795 - loss: 0.4310 - val_accuracy: 0.6973 - val_loss: 1.0600
# Epoch 12/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 100ms/step - accuracy: 0.8831 - loss: 0.3972 - val_accuracy: 0.6752 - val_loss: 1.2019
# Epoch 13/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.8359 - loss: 0.5624 - val_accuracy: 0.7358 - val_loss: 0.9636
# Epoch 14/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.8992 - loss: 0.3381 - val_accuracy: 0.6244 - val_loss: 1.4584
# Epoch 15/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.8143 - loss: 0.6625 - val_accuracy: 0.6914 - val_loss: 1.1805
# Epoch 16/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.8860 - loss: 0.3952 - val_accuracy: 0.7503 - val_loss: 0.9422
# Epoch 17/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.9399 - loss: 0.2188 - val_accuracy: 0.7900 - val_loss: 0.8218
# Epoch 18/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.9565 - loss: 0.1682 - val_accuracy: 0.7909 - val_loss: 0.8199
# Epoch 19/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.9588 - loss: 0.1603 - val_accuracy: 0.7859 - val_loss: 0.8262
# Epoch 20/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.9703 - loss: 0.1210 - val_accuracy: 0.7969 - val_loss: 0.8333
# Epoch 21/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.9713 - loss: 0.1143 - val_accuracy: 0.7657 - val_loss: 0.9429
# Epoch 22/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.9684 - loss: 0.1151 - val_accuracy: 0.7819 - val_loss: 0.9203
# Epoch 23/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - accuracy: 0.9782 - loss: 0.0875 - val_accuracy: 0.7793 - val_loss: 0.9357
# Epoch 24/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 104ms/step - accuracy: 0.9594 - loss: 0.1325 - val_accuracy: 0.7966 - val_loss: 0.8937
# Epoch 25/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - accuracy: 0.9677 - loss: 0.1072 - val_accuracy: 0.8000 - val_loss: 0.9068
# Epoch 26/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 25s 95ms/step - accuracy: 0.9839 - loss: 0.0645 - val_accuracy: 0.7964 - val_loss: 0.9195
# Epoch 27/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 25s 96ms/step - accuracy: 0.9851 - loss: 0.0587 - val_accuracy: 0.8085 - val_loss: 0.8795
# Epoch 28/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - accuracy: 0.9809 - loss: 0.0689 - val_accuracy: 0.8023 - val_loss: 0.9235
# Epoch 29/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.9832 - loss: 0.0644 - val_accuracy: 0.7798 - val_loss: 1.1064
# Epoch 30/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.9847 - loss: 0.0567 - val_accuracy: 0.8194 - val_loss: 0.8915
# Epoch 31/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.9858 - loss: 0.0517 - val_accuracy: 0.7943 - val_loss: 1.0208
# Epoch 32/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.9658 - loss: 0.0997 - val_accuracy: 0.7833 - val_loss: 1.1418
# Epoch 33/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.9628 - loss: 0.1202 - val_accuracy: 0.7529 - val_loss: 1.2967
# Epoch 34/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.9789 - loss: 0.0655 - val_accuracy: 0.8187 - val_loss: 0.9592
# Epoch 35/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.9806 - loss: 0.0666 - val_accuracy: 0.8323 - val_loss: 0.9193
# Epoch 36/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 104ms/step - accuracy: 0.9951 - loss: 0.0220 - val_accuracy: 0.8057 - val_loss: 1.0400
# Epoch 37/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - accuracy: 0.9887 - loss: 0.0383 - val_accuracy: 0.8163 - val_loss: 0.9828
# Epoch 38/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.9948 - loss: 0.0239 - val_accuracy: 0.8000 - val_loss: 1.1277
# Epoch 39/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 103ms/step - accuracy: 0.9677 - loss: 0.0916 - val_accuracy: 0.7862 - val_loss: 1.1996
# Epoch 40/40
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 27s 103ms/step - accuracy: 0.9582 - loss: 0.1370 - val_accuracy: 0.8128 - val_loss: 1.0220

# %%
# Record the end time after compilation
end_time = time.time()

# Calculate and print the compilation time
compilation_time = end_time - start_time
print(f"Model compilation time: {compilation_time} seconds")
# Out:
# Model compilation time: 1084.996309518814 seconds

# %%
# Plot accuracy and validation accuracy graphs
plt.plot(history_2.history['accuracy'], label='Training Accuracy')
plt.plot(history_2.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss:.4f}, Test accuracy: {accuracy * 100:.2f}%')
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8155 - loss: 1.0031
# Test loss: 1.0185, Test accuracy: 81.28%

# %%
# Use the trained model to predict classes on the test set
predictions = model.predict(X_test)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Decode the encoded labels back to the original labels
decoded_predicted_labels = label_encoder.inverse_transform(predicted_labels)
decoded_true_labels = label_encoder.inverse_transform(y_test)

# Display only the true predicted images
num_images_to_display = 5
count = 0

for i in range(len(X_test)):
    if decoded_true_labels[i] == decoded_predicted_labels[i]:
        plt.figure(figsize=(4, 4))
        plt.imshow(X_test[i])
        plt.title(f"True: {decoded_true_labels[i]}, Predicted: {decoded_predicted_labels[i]}")
        plt.show()
        count += 1

        if count == num_images_to_display:
            break
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step

# %%
# Use the trained model to predict classes on the test set
predictions = model.predict(X_test)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Decode the encoded labels back to the original labels
decoded_predicted_labels = label_encoder.inverse_transform(predicted_labels)
decoded_true_labels = label_encoder.inverse_transform(y_test)

# Display only the wrong predicted images
num_wrong_images_to_display = 5
count = 0

for i in range(len(X_test)):
    if decoded_true_labels[i] != decoded_predicted_labels[i]:
        plt.figure(figsize=(4, 4))
        plt.imshow(X_test[i])
        plt.title(f"True: {decoded_true_labels[i]}, Predicted: {decoded_predicted_labels[i]}")
        plt.show()
        count += 1

        if count == num_wrong_images_to_display:
            break
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step
